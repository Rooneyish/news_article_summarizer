# %% [markdown]
# <a href="https://colab.research.google.com/github/Rooneyish/news_article_summarizer/blob/main/Text_summarizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U spacy beautifulsoup4 requests newspaper3k

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 91.5 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# !pip install lxml_html_clean

# %%
from newspaper import Article

def getArticle(url):
  try:
    article = Article(url)
    article.download()
    article.parse()
    return article.text
  except Exception as e:
    print(f"Error while extrating Article: {url} : {e}")
    return None

# %%
import pandas as pd

test_data = pd.read_csv("/content/drive/MyDrive/News Article Summary 1 GB/Test.csv")
train_data = pd.read_csv("/content/drive/MyDrive/News Article Summary 1 GB/Train.csv")
val_data = pd.read_csv("/content/drive/MyDrive/News Article Summary 1 GB/validation.csv")

# %%
train_data.sample(5)
# Out:
#                                               id  \
# 32693   5ceb444fa1adc91e8d2e47386ae46b1db6c0ead9
# 231750  b80fa2dad2ee92e63cbb3784b2ba4d350d389128
# 206477  97511cc39ccf9175622bebf8496b94800db46a45
# 216225  a3e9230dacdc7afef73c5f45d94f76709c6ceb88
# 183307  796df28017dedce66088a19f49666085fe1b5a49
#
#                                                   article  \
# 32693   Lushan, China (CNN) -- A strong earthquake tha...
# 231750  MPs are demanding full ‘home rule’ for England...
# 206477  Pensacola, Florida (CNN) -- The man who prosec...
# 216225  By . Matt Chorley, Mailonline Political Editor...
# 183307  Dozens of loaded firearms, inert military gren...
#
#                                                highlights
# 32693   NEW: 186 people are dead and 8,200 hospitalize...
# 231750  English MPs now want their own 'home rule' fol...
# 206477  NEW: A jury finds Leonard Gonzalez Jr. guilty ...
# 216225  Watchdog says it is 'difficult to comprehend' ...
# ...

# %%
test_data.sample(5)
# Out:
#                                             id  \
# 1524  bc3b61a5da3631121708419b945d975df9f6826f
# 4588  5744aa7cfd227d29b625aa606a32dba6567d71ed
# 3109  d9107bdad9b67a69b94af3d58e9c51f8930902a2
# 7917  e4034f21c7fbfdd6b700ac607306da8a6d651f17
# 6705  5cca2ec6d021fda0db96aa41a1d5c5cc9bbb3894
#
#                                                 article  \
# 1524  This is the moment that three teenage vandals ...
# 4588  Hollie Tillbrook, 17, was saved by two off-dut...
# 3109  Great-grandmother: Gloria Ross, 84, died follo...
# 7917  James May has been forced to backtrack for sug...
# 6705  The Tesla Model S P85D's 'insane mode' may be ...
#
#                                              highlights
# 1524  Gang target car dealership in Dearborn Heights...
# 4588  Hollie Tillbrook's heart momentarily stopped a...
# 3109  Gloria Ross was found with a distorted face wh...
# 7917  James May has backtracked on comment suggestin...
# 6705  eO PP03 runs on 50 kWh lithium-ion battery pac...

# %%
val_data.sample(5)
# Out:
#                                              id  \
# 10248  142bb186bc99efaed845092d2bb7a49a378371b7
# 11778  2ee20c312b6f254091fa15994d90d775a99d1a0a
# 12175  5ec0b3d73f074bd29ae5da08c17b82d76a2ab999
# 10422  b4b74a3c1fbb1844160e61f0450b60c5c99d2e62
# 11525  ed6126a2700a2ad4e9105f1cc2fc5478f426d808
#
#                                                  article  \
# 10248  The Budget has failed to provide a Tory bounce...
# 11778  Paul Murray admits the new Rangers regime is s...
# 12175  In a season when Manchester United’s aspiratio...
# 10422  An anguished daughter has begged her father to...
# 11525  Sam Allardyce believes a lack of winter break ...
#
#                                               highlights
# 10248  If economy stays on track until the Election, ...
# 11778  Rangers took a £5million loan from Sports Dire...
# 12175  Manchester United's only remaining goal is to ...
# 10422  Veronica Packman, 40, went missing from her Bo...
# ...

# %%
train_data.shape[0], test_data.shape[0], val_data.shape[0]
# Out:
# (287113, 11490, 13368)

# %%
X_train = train_data.iloc[:,1]
X_val = val_data.iloc[:,1]
X_test = test_data.iloc[:,1]

# %%
X_train.head()
# Out:
# 0    By . Associated Press . PUBLISHED: . 14:11 EST...
# 1    (CNN) -- Ralph Mata was an internal affairs li...
# 2    A drunk driver who killed a young woman in a h...
# 3    (CNN) -- With a breezy sweep of his pen Presid...
# 4    Fleetwood are the only team still to have a 10...
# Name: article, dtype: object

# %%
X_test.head()
# Out:
# 0    Ever noticed how plane seats appear to be gett...
# 1    A drunk teenage boy had to be rescued by secur...
# 2    Dougie Freedman is on the verge of agreeing a ...
# 3    Liverpool target Neto is also wanted by PSG an...
# 4    Bruce Jenner will break his silence in a two-h...
# Name: article, dtype: object

# %%
X_val.head()
# Out:
# 0    Sally Forrest, an actress-dancer who graced th...
# 1    A middle-school teacher in China has inked hun...
# 2    A man convicted of killing the father and sist...
# 3    Avid rugby fan Prince Harry could barely watch...
# 4    A Triple M Radio producer has been inundated w...
# Name: article, dtype: object

# %%
y_train = train_data.iloc[:,-1]
y_test = test_data.iloc[:, -1]
y_val = val_data.iloc[:,-1]

# %%
y_train.head()
# Out:
# 0    Bishop John Folda, of North Dakota, is taking ...
# 1    Criminal complaint: Cop used his role to help ...
# 2    Craig Eccleston-Todd, 27, had drunk at least t...
# 3    Nina dos Santos says Europe must be ready to a...
# 4    Fleetwood top of League One after 2-0 win at S...
# Name: highlights, dtype: object

# %%
y_test.head()
# Out:
# 0    Experts question if  packed out planes are put...
# 1    Drunk teenage boy climbed into lion enclosure ...
# 2    Nottingham Forest are close to extending Dougi...
# 3    Fiorentina goalkeeper Neto has been linked wit...
# 4    Tell-all interview with the reality TV star, 6...
# Name: highlights, dtype: object

# %%
y_val.head()
# Out:
# 0    Sally Forrest, an actress-dancer who graced th...
# 1    Works include pictures of Presidential Palace ...
# 2    Iftekhar Murtaza, 29, was convicted a year ago...
# 3    Prince Harry in attendance for England's crunc...
# 4    Nick Slater's colleagues uploaded a picture to...
# Name: highlights, dtype: object
